# %% [markdown]
# <a href="https://colab.research.google.com/github/Michellog/Agente-IA/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
nome = "Jornada de Dados"
print(f"Olá, {nome}")
# Out:
# Olá, Jornada de Dados

# %%
nome_produto = "Tênis Nike Air Max"
categoria = 'Tênis'

# %%
quantidade = 10
total_produtos = 200

# %%
tenis = ["Tênis Nike Air Max", "Tênis Adidas Ultraboost", "Tênis Puma RS-X"]
precos = [599.90, 699.90, 449.90]

# %%
tenis_nike = {
    "nome": "Tênis Nike Air Max",
    "marca": "Nike",
    "categoria": "Tênis",
    "preco": 599.90,
    "quantidade": 10
}

print(tenis_nike)
# Out:
# {'nome': 'Tênis Nike Air Max', 'marca': 'Nike', 'categoria': 'Tênis', 'preco': 599.9, 'quantidade': 10}

# %%
print(tenis_nike)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_711/1706397338.py in <cell line: 0>()
# ----> 1 print(tenis_nike)
#
# NameError: name 'tenis_nike' is not defined

# %%
lista_tenis = [
    {"nome": "Tênis Nike Air Max", "marca": "Nike", "preco": 599.90},
    {"nome": "Tênis Adidas Ultraboost", "marca": "Adidas", "preco": 699.90},
    {"nome": "Tênis Puma RS-X", "marca": "Puma", "preco": 449.90},
    {"nome": "Tênis Vans Old Skool", "marca": "Vans", "preco": 399.90},
    {"nome": "Tênis Converse Chuck", "marca": "Converse", "preco": 349.90}
]

for tenis_item in lista_tenis:
    print(f"{tenis_item['nome']} - R$ {tenis_item['preco']}")
# Out:
# Tênis Nike Air Max - R$ 599.9
# Tênis Adidas Ultraboost - R$ 699.9
# Tênis Puma RS-X - R$ 449.9
# Tênis Vans Old Skool - R$ 399.9
# Tênis Converse Chuck - R$ 349.9
